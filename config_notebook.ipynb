# %% [markdown]
# **For RAW**

# %%
base_urls = {
    "Patient": "https://hapi.fhir.org/baseR4/Patient",
    "Encounter": "https://hapi.fhir.org/baseR4/Encounter",
    "Observation": "https://hapi.fhir.org/baseR4/Observation",
    "Condition": "https://hapi.fhir.org/baseR4/Condition"
}

raw_root = "dbfs:/Volumes/workspace/default/fhir_files/raw"

# %% [markdown]
# **For BRONZE**

# %%
raw_filepaths={
    "Patient":{"raw_path":f"{raw_root}/patient/","table_name":"workspace.default.bronze_patient"},
    "Encounter":{"raw_path":f"{raw_root}/encounter/","table_name":"workspace.default.bronze_encounter"},
    "Observation":{"raw_path":f"{raw_root}/observation/","table_name":"workspace.default.bronze_observation"},
    "Condition":{"raw_path":f"{raw_root}/condition/","table_name":"workspace.default.bronze_condition"}
}

# %%
dbutils.notebook.exit('Success')
