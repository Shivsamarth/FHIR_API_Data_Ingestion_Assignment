# %% [markdown]
# **bronze**

# %%
# %sql
create table if not exists workspace.silver.silver_patient(
    active boolean,
    address array<struct<
        city:string,
        country:string,
        district:string,
        line:array<string>,
        period:struct<start:string>,
        postalCode:string,
        state:string,
        text:string,
        type:string,
        use:string
    >>,
    birthDate string,
    communication array<struct<
        language:struct<
            coding:array<struct<
                code:string,
                display:string,
                system:string
            >>,
            text:string
        >,
        preferred:boolean
    >>,
    contact array<struct<
        name:struct<
            family:string,
            given:array<string>,
            text:string,
            use:string
        >,
        relationship:array<struct<
            coding:array<struct<
                code:string,
                display:string,
                system:string
            >>,
            text:string
        >>,
        telecom:array<struct<
            system:string,
            use:string,
            value:string
        >>
    >>,
    deceasedBoolean boolean,
    extension array<struct<
        url:string,
        valueBoolean:boolean,
        valueCodeableConcept:struct<
            coding:array<struct<
                code:string,
                display:string,
                system:string
            >>,
            text:string
        >,
        valueQuantity:struct<
            code:string,
            system:string,
            unit:string,
            value:double
        >,
        valueString:string
    >>,
    gender string,
    generalPractitioner array<struct<
        display:string,
        reference:string
    >>,
    id string,
    identifier array<struct<
        system:string,
        type:struct<
            coding:array<struct<
                code:string,
                display:string,
                system:string
            >>,
            text:string
        >,
        use:string,
        value:string
    >>,
    link array<struct<
        other:struct<
            reference:string
        >,
        type:string
    >>,
    managingOrganization struct<
        display:string,
        reference:string
    >,
    maritalStatus struct<
        coding:array<struct<
            code:string,
            display:string,
            system:string
        >>,
        text:string
    >,
    meta struct<
        lastUpdated:string,
        profile:array<string>,
        security:array<struct<
            code:string,
            display:string,
            system:string
        >>,
        source:string,
        tag:array<struct<
            code:string,
            display:string,
            system:string
        >>,
        versionId:string
    >,
    multipleBirthBoolean boolean,
    name array<struct<
        _given:array<struct<
            extension:array<struct<
                url:string,
                valueString:string
            >>
        >>,
        family:string,
        given:array<string>,
        suffix:array<string>,
        text:string,
        use:string
    >>,
    resourceType string,
    telecom array<struct<
        rank:bigint,
        system:string,
        use:string,
        value:string
    >>,
    text struct<
        div:string,
        status:string
    >,
    file_path string,
    extraction_timestamp timestamp,
    api_url_or_params string
)
using delta;

# %% [markdown]
# **silver**

# %%
    # %sql
    create table if not exists workspace.silver.silver_patient (
        active boolean,
        address array<struct<
            city:string,
            country:string,
            district:string,
            line:array<string>,
            period:struct<start:string>,
            postalCode:string,
            state:string,
            text:string,
            type:string,
            use:string
        >>,
        birthDate string,
        communication array<struct<
            language:struct<
                coding:array<struct<
                    code:string,
                    display:string,
                    system:string
                >>,
                text:string
            >,
            preferred:boolean
        >>,
        contact array<struct<
            address:struct<
                city:string,
                district:string,
                line:array<string>,
                period:struct<start:string>,
                postalCode:string,
                state:string,
                type:string,
                use:string
            >,
            gender:string,
            modifierExtension:array<struct<
                url:string,
                valueBoolean:boolean
            >>,
            name:struct<
                _family:struct<
                    extension:array<struct<
                        url:string,
                        valueString:string
                    >>
                >,
                family:string,
                given:array<string>,
                use:string
            >,
            period:struct<start:string>,
            relationship:array<struct<
                coding:array<struct<
                    code:string,
                    display:string,
                    system:string
                >>
            >>,
            telecom:array<struct<
                system:string,
                use:string,
                value:string
            >>
        >>,
        extension array<struct<
            url:string,
            valueBoolean:boolean,
            valueCode:string,
            valueCodeableConcept:struct<
                coding:array<struct<
                    code:string,
                    display:string,
                    system:string
                >>,
                text:string
            >,
            valueCoding:struct<
                code:string,
                display:string,
                system:string
            >,
            valueDecimal:bigint,
            valueInteger:bigint,
            valueString:string
        >>,
        gender string,
        generalPractitioner array<struct<
            display:string,
            reference:string
        >>,
        id string,
        identifier array<struct<
            assigner:struct<display:string>,
            period:struct<start:string>,
            system:string,
            type:struct<
                coding:array<struct<
                    code:string,
                    display:string,
                    system:string
                >>,
                text:string
            >,
            use:string,
            value:string
        >>,
        managingOrganization struct<
            display:string,
            reference:string
        >,
        maritalStatus struct<
            coding:array<struct<
                code:string,
                display:string,
                system:string
            >>,
            text:string
        >,
        meta struct<
            lastUpdated:string,
            profile:array<string>,
            source:string,
            tag:array<struct<
                code:string,
                display:string,
                system:string
            >>,
            versionId:string
        >,
        name array<struct<
            family:string,
            given:array<string>,
            period:struct<end:string>,
            prefix:array<string>,
            suffix:array<string>,
            text:string,
            use:string
        >>,
        resourceType string,
        telecom array<struct<
            period:struct<end:string>,
            rank:bigint,
            system:string,
            use:string,
            value:string
        >>,
        text struct<
            div:string,
            status:string
        >,
        file_path string,
        extraction_timestamp timestamp,
        api_url_or_params string,
        silver_processed_timestamp timestamp,
        is_current boolean,
        effective_start_date timestamp,
        effective_end_date timestamp
    )
    using delta;

# %%
spark.sql("""create table if not exists workspace.silver.silver_encounter(account array<struct<display:string>>,appointment array<struct<display:string,reference:string>>,basedOn array<struct<display:string>>,class struct<code:string,display:string,system:string>,classHistory array<struct<class:struct<code:string,display:string,system:string>,period:struct<start:string>>>,contained array<struct<address:struct<city:string,country:string,line:array<string>,postalCode:string,state:string>,description:string,id:string,name:string,physicalType:struct<coding:array<struct<code:string,display:string,system:string>>>,resourceType:string,telecom:array<struct<system:string,use:string,value:string>>,type:array<struct<coding:array<struct<code:string,display:string,system:string>>>>>>,diagnosis array<struct<condition:struct<display:string,reference:string>,rank:bigint,use:struct<coding:array<struct<code:string,display:string,system:string>>>>>,episodeOfCare array<struct<display:string>>,hospitalization struct<admitSource:struct<coding:array<struct<code:string,display:string,system:string>>>,destination:struct<display:string>,dietPreference:array<struct<coding:array<struct<code:string,display:string,system:string>>>>,dischargeDisposition:struct<coding:array<struct<code:string,display:string,system:string>>>,origin:struct<display:string>,preAdmissionIdentifier:struct<system:string,use:string,value:string>,reAdmission:struct<coding:array<struct<code:string,display:string,system:string>>>,specialArrangement:array<struct<coding:array<struct<code:string,display:string,system:string>>>>,specialCourtesy:array<struct<coding:array<struct<code:string,display:string,system:string>>>>>,id string,identifier array<struct<system:string,use:string,value:string>>,length struct<code:string,system:string,unit:string,value:bigint>,location array<struct<location:struct<display:string,reference:string>,period:struct<end:string,start:string>,physicalType:struct<coding:array<struct<code:string,display:string,system:string>>>,status:string>>,meta struct<lastUpdated:string,profile:array<string>,source:string,tag:array<struct<code:string,display:string,system:string>>,versionId:string>,partOf struct<display:string>,participant array<struct<individual:struct<display:string,identifier:struct<system:string,value:string>,reference:string>,period:struct<end:string,start:string>,type:array<struct<coding:array<struct<code:string,display:string,system:string>>>>>>,period struct<end:string,start:string>,priority struct<coding:array<struct<code:string,display:string,system:string>>>,reasonCode array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,reasonReference array<struct<display:string>>,resourceType string,serviceProvider struct<display:string,identifier:struct<system:string,value:string>,reference:string>,serviceType struct<coding:array<struct<code:string,display:string,system:string>>,text:string>,status string,statusHistory array<struct<period:struct<start:string>,status:string>>,subject struct<display:string,reference:string>,type array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,file_path string,extraction_timestamp timestamp,api_url_or_params string,silver_processed_timestamp timestamp,is_current boolean,effective_start_date timestamp,effective_end_date timestamp)using delta""")

# %% [markdown]
# **gold**

# %%
# %sql
create table if not exists workspace.gold.gold_patient_observation(
patient_id string,
gender string,
birthDate string,
observation_id string,
observation_status string,
observation_name string,
observation_code string,
observation_display string,
observation_value string,
observation_date string,
category array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,
interpretation array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,
referenceRange array<struct<high:struct<code:string,system:string,unit:string,value:double>,low:struct<code:string,system:string,unit:string,value:double>,text:string>>,
observation_last_updated string,
gold_processed_timestamp timestamp
)
using delta;

# %%
# %sql
create table if not exists workspace.gold.gold_patient_condition(
patient_id string,
gender string,
birthDate string,
condition_id string,
clinical_status_code string,
verification_status_code string,
condition_name string,
condition_code string,
condition_onset_date string,
severity struct<coding:array<struct<code:string,display:string,system:string>>,text:string>,
bodySite array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,
condition_last_updated string,
gold_processed_timestamp timestamp
)
using delta;

# %%
# %sql
create table if not exists workspace.gold.gold_patient_encounter(
patient_id string,
gender string,
birthDate string,
encounter_id string,
encounter_status string,
encounter_class_code string,
encounter_class_display string,
type array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,
encounter_start string,
encounter_end string,
participant array<struct<individual:struct<display:string,reference:string>,type:array<struct<coding:array<struct<code:string,display:string,system:string>>>>>>,
serviceProvider struct<display:string,identifier:struct<system:string,value:string>,reference:string>,
reasonCode array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,
diagnosis array<struct<condition:struct<display:string,reference:string>>>,
location array<struct<location:struct<display:string,identifier:struct<system:string,value:string>,reference:string>,period:struct<start:string>,status:string>>,
encounter_last_updated string,
gold_processed_timestamp timestamp
)
using delta;

# %%
# %sql
create table if not exists workspace.gold.gold_patient_summary(
patient_id string,
gender string,
birthDate string,
marital_status string,
encounter_count bigint,
observation_count bigint,
condition_count bigint,
gold_processed_timestamp timestamp
)
using delta;

# %%
# %sql
create table if not exists workspace.gold.gold_condition_summary(
condition_name string,
condition_code string,
condition_display string,
condition_count bigint,
patient_count bigint,
gold_processed_timestamp timestamp
)
using delta;
